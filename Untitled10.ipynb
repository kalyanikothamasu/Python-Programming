# %%
from google.colab import userdata
import google.generativeai as genai

api_key = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-2.5-pro')

response = model.generate_content('Tell about AI')

print(response.text)
# Out:
# Of course! Here is a comprehensive overview of Artificial Intelligence (AI), broken down into simple, easy-to-understand sections.
#
# ### 1. What is Artificial Intelligence (AI)?
#
# At its core, **Artificial Intelligence is the science of making machines smart.** It's a broad field of computer science dedicated to creating systems that can perform tasks that typically require human intelligence.
#
# These tasks include:
# *   **Learning** from experience.
# *   **Reasoning** and solving problems.
# *   **Understanding** human language.
# *   **Perceiving** the world (seeing, hearing).
# *   **Interacting** with the physical world (like in robotics).
#
# Think of it this way: a traditional computer program follows explicit, pre-written instructions. An AI system, on the other hand, can **learn and adapt** on its own to achieve a goal.
#
# ---
#
# ### 2. How Does AI Learn? (A Simple View)
#
# Most modern AI systems learn through a process called **Machine Learning**. The basic idea is:
#
# 1.  **Feed it Data:** You give the AI a massive amount of data. For example, to teach an AI to recognize cats, you would show it millions of pictures, some labeled "cat" and some labeled "not a cat."
# 2.  **Find Patterns:** The AI's algorithm sifts through this data to find patterns. It learns the specific features (pointy ears, whiskers, fur patterns) that are consistently associated with the "cat" label.
# 3.  **Create a Model:** Based on these patterns, the AI builds an internal "model." This model is essentially its own understanding of what a cat looks like.
# 4.  **Make Predictions:** Now, when you show it a *new* picture it has never seen before, it uses its model to predict whether it's a cat. The more data and training it gets, the more accurate its predictions become.
#
# ---
#
# ### 3. The Main Types of AI
#
# AI is often categorized in two ways: by its **capability** and its **functionality**.
#
# #### By Capability (The Most Common Way):
#
# *   **Artificial Narrow Intelligence (ANI):** This is the only type of AI we have today. ANI is designed to perform a *single, specific task* very well. It operates within a limited, pre-defined range.
#     *   **Examples:** Siri/Alexa, Google's search algorithm, the AI that recommends shows on Netflix, self-driving cars, and facial recognition software. While powerful, they can't operate outside their specific domain. Siri can't drive a car, and a Netflix AI can't diagnose a disease.
#
# *   **Artificial General Intelligence (AGI):** This is the AI you see in movies, like Data from *Star Trek* or the helpers in *Her*. AGI would have the ability to understand, learn, and apply its intelligence to solve *any* problem, much like a human being. **We have not achieved AGI yet.** It remains a theoretical and long-term goal for researchers.
#
# *   **Artificial Superintelligence (ASI):** This is a hypothetical future AI that would surpass human intelligence in every conceivable way—from scientific creativity and general wisdom to social skills. This is the type of AI that raises discussions about existential risks.
#
# ---
#
# ### 4. Key Subfields of AI
#
# AI is a vast field with many specialized areas. Here are the most important ones:
#
# *   **Machine Learning (ML):** The engine that powers most modern AI. It's the process of teaching systems to learn from data without being explicitly programmed.
# *   **Deep Learning:** A more advanced subset of Machine Learning that uses "neural networks" with many layers (hence "deep"). These networks are inspired by the structure of the human brain and are incredibly effective at finding complex patterns in huge datasets. Deep learning is behind most recent breakthroughs, like advanced image recognition and natural language models (like the one you are interacting with now!).
# *   **Natural Language Processing (NLP):** This focuses on enabling computers to understand, interpret, and generate human language.
#     *   **Examples:** Chatbots, language translation (Google Translate), spam email filters, and sentiment analysis (determining if a review is positive or negative).
# *   **Computer Vision:** This field teaches computers to "see" and interpret visual information from the world.
#     *   **Examples:** Facial recognition on your phone, self-driving cars identifying obstacles, and medical imaging analysis.
# *   **Robotics:** This involves designing and building robots. When robotics is combined with AI, you get intelligent robots that can navigate and interact with their environment.
#
# ---
#
# ### 5. Everyday Examples of AI
#
# You use AI every day, often without realizing it:
#
# *   **Recommendation Engines:** Netflix, YouTube, and Spotify learn your preferences to suggest what you might like next.
# *   **Virtual Assistants:** Siri, Alexa, and Google Assistant use NLP to understand your commands.
# *   **Navigation Apps:** Google Maps and Waze use AI to analyze traffic data in real-time to find the fastest route.
# *   **Spam Filters:** Your email service uses AI to learn the characteristics of junk mail and move it out of your inbox.
# *   **Social Media Feeds:** Facebook, Instagram, and TikTok use AI to curate your feed based on what you've engaged with in the past.
# *   **Banking:** AI is used to detect fraudulent transactions by identifying unusual patterns in your spending.
#
# ---
#
# ### 6. Ethical Concerns and Challenges
#
# The rise of AI also brings significant challenges that society is actively debating:
#
# *   **Bias:** If the data used to train an AI is biased, the AI's decisions will also be biased. For example, a hiring AI trained on historical data might discriminate against women if past hiring practices were biased.
# *   **Job Displacement:** AI and automation could replace jobs that involve repetitive tasks, raising questions about the future of work.
# *   **Privacy:** AI systems require vast amounts of data, leading to concerns about how personal information is collected, stored, and used.
# *   **Security:** AI can be used for malicious purposes, such as creating sophisticated cyberattacks, autonomous weapons, or deepfake videos for misinformation.
# *   **The "Black Box" Problem:** With some complex deep learning models, even the creators don't fully understand *how* the AI reached a specific conclusion, making it difficult to trust or debug.
#
# ### Conclusion
#
# Artificial Intelligence is no longer science fiction. It's a powerful and transformative technology that is already reshaping our world. While the AI we have today is "narrow," its capabilities are growing exponentially, offering immense potential to solve some of humanity's biggest challenges in medicine, climate change, and science. At the same time, it requires careful, ethical development and regulation to ensure its benefits are shared by all and its risks are managed responsibly.
