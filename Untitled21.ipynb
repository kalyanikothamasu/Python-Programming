# %%
import numpy as np
n = 5
x_pos = np.random.uniform(0, 10, n)
y_pos = np.random.uniform(0, 10, n)
offsets = np.column_stack([x_pos, y_pos])
print(f'x-pos is {x_pos}')
print(f'y-pos is {y_pos}')
print(f'offsets is {offsets}')
# Out:
# x-pos is [5.41565305 2.35799161 6.40658006 1.38762019 9.05233702]
# y-pos is [4.21403409 7.16454301 4.170105   9.35273519 6.82913797]
# offsets is [[5.41565305 4.21403409]
#  [2.35799161 7.16454301]
#  [6.40658006 4.170105  ]
#  [1.38762019 9.35273519]
#  [9.05233702 6.82913797]]
