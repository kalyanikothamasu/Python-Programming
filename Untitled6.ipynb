# %%
[i*'*', end='' for i in range(6)]

# %%
left_triangle_pattern=[ i*'*' for i in range(1,6)]
for i in left_triangle_pattern:
    print(i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
# using list conmprehension Method for pattern's
#illustrating each line of the code line by line
# left_triangele_pattern=[i*'*' for i in range(1,6)]# Just run this code you will get a list of patterns with stars
# left_triangele_pattern
# for i in left_triangele_pattern:
#     print(i)
right_triangle_pattern=[((6-i)*' '+i*'*') for i in range(1,6)]
for i in right_triangle_pattern:
  print(i)
#inverted left align Triangle:
inverted_left_triangle_pattern=[((6-i)*' '+i*'*') for i in range(5,0,-1)]
for i in inverted_left_triangle_pattern:
  print(i)
# Out:
#      *
#     **
#    ***
#   ****
#  *****
#  *****
#   ****
#    ***
#     **
#      *

# %%
#inverted left align Triangle: using list comprehension in reverse order
inverted_left_triangle_pattern=[(i*'* ')+(2*(5-i)*' ')+ i * '* ' for i in range(5,0,-1)]
for i in inverted_left_triangle_pattern:
  print(i)
right_triangle_pattern=[((5-i)*' '+i*'*') for i in range(5,0,-1)]
for i in right_triangle_pattern:
  print(i)
# Out:
# * * * * * * * * * *
# * * * *   * * * *
# * * *     * * *
# * *       * *
# *         *
# *****
#  ****
#   ***
#    **
#     *
